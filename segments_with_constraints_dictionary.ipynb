# %%
# All 30 segments
segments = [('A', 'B', 20), ('B', 'C', 65), ('C', 'D', 55), ('D', 'E', 19), ('E', 'F', 80), ('F', 'G', 45), ('G', 'H', 95), ('H', 'I', 70), ('I', 'J', 110), ('J', 'K', 150), ('K', 'L', 90), ('L', 'M', 65), ('M', 'A', 128), ('D', 'K', 43), ('C', 'G', 43), ('E', 'G', 57), ('G', 'I', 61), ('F', 'I', 88), ('K', 'I', 78), ('H', 'J', 143), ('B', 'E', 85), ('A', 'D', 110), ('B', 'F', 130), ('D', 'F', 90), ('H', 'K', 140), ('C', 'F', 100), ('M', 'J', 160), ('L', 'H', 120), ('M', 'I', 85), ('E', 'J', 180)]
print(f"Total segments: {len(segments)}")

# %%
# Constraints on specific segments
constraints = {('C', 'D'): 'stairs', ('E', 'F'): 'kerb_ramp', ('H', 'I'): 'lift', ('C', 'F'): 'obstacle', ('J', 'K'): 'slope', ('K', 'I'): 'slope', ('A', 'D'): 'stairs', ('L', 'H'): 'lift', ('M', 'J'): 'slope', ('B', 'F'): 'kerb_ramp'}
