# %%
# Updated segment list with terrain constraints
segments = [
    ('A', 'B', 20, 'flat'),
    ('B', 'C', 65, 'slope'),
    ('C', 'D', 55, 'stairs'),
    ('D', 'E', 19, 'flat'),
    ('E', 'F', 80, 'kerb_ramp'),
    ('F', 'G', 45, 'flat'),
    ('G', 'H', 95, 'flat'),
    ('H', 'I', 70, 'lift'),
    ('I', 'J', 110, 'flat'),
    ('J', 'K', 150, 'slope'),
    ('K', 'L', 90, 'flat'),
    ('L', 'M', 65, 'flat'),
    ('M', 'A', 128, 'flat'),
    ('D', 'K', 43, 'slope'),
    ('C', 'G', 43, 'kerb_ramp'),
    ('E', 'G', 57, 'flat'),
    ('G', 'I', 61, 'flat'),
    ('F', 'I', 88, 'flat'),
    ('K', 'I', 78, 'slope'),
    ('H', 'J', 143, 'lift'),
    ('B', 'E', 85, 'flat'),
    ('A', 'D', 110, 'stairs'),
    ('B', 'F', 130, 'kerb_ramp'),
    ('D', 'F', 90, 'flat'),
    ('H', 'K', 140, 'flat'),
    ('C', 'F', 100, 'obstacle'),
    ('M', 'J', 160, 'slope'),
    ('L', 'H', 120, 'lift'),
    ('M', 'I', 85, 'flat'),
    ('E', 'J', 180, 'flat')
]

# Display the total number of segments
len(segments)
